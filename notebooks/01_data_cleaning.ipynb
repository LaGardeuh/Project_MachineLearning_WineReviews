# %% [markdown]
# # Cleaning and preparing of the wine dataset

# %%
import pandas as pd

file_path = "../data/raw/winemag-data-130k-v2.csv"

# %% [markdown]
# # Loading and cleaning by chunks

# %%
chunksize = 20000
clean_chunks = []

for chunk in pd.read_csv(file_path, chunksize=chunksize):
    # Renommage des colonnes
    chunk = chunk.rename(columns={
        "Unnamed: 0": "id",
        "region_1": "primary_region",
        "region_2": "secondary_region",
    })

    # Deleting completely empty lines
    chunk = chunk.dropna(how="all")

    # Removing duplicates
    chunk = chunk.drop_duplicates()

    clean_chunks.append(chunk)

# Concaténation de tous les chunks
df_clean = pd.concat(clean_chunks, ignore_index=True)

# Final removal of duplicates across the entire dataset
df_clean = df_clean.drop_duplicates()

print(f"Number of lines after cleaning : {len(df_clean)}")
print(f"\nData overview :")
print(df_clean.head())
# Out:
# Number of lines after cleaning : 129971
#
# Data overview :
#    id   country                                        description  \
# 0   0     Italy  Aromas include tropical fruit, broom, brimston...
# 1   1  Portugal  This is ripe and fruity, a wine that is smooth...
# 2   2        US  Tart and snappy, the flavors of lime flesh and...
# 3   3        US  Pineapple rind, lemon pith and orange blossom ...
# 4   4        US  Much like the regular bottling from 2012, this...
#
#                           designation  points  price           province  \
# 0                        Vulkà Bianco      87    NaN  Sicily & Sardinia
# 1                            Avidagos      87   15.0              Douro
# 2                                 NaN      87   14.0             Oregon
# 3                Reserve Late Harvest      87   13.0           Michigan
# 4  Vintner's Reserve Wild Child Block      87   65.0             Oregon
#
#         primary_region   secondary_region         taster_name  \
# ...

# %% [markdown]
# ## Deleting columns `secondary_region` and `taster_twitter_handle` and the lines with empty values

# %%
if "secondary_region" in df_clean.columns:
    df_clean = df_clean.drop("secondary_region", axis=1)
else:
    print('Column secondary_region doesn\'t exist.')
if "taster_twitter_handle" in df_clean.columns:
    df_clean = df_clean.drop("taster_twitter_handle", axis=1)
else:
    print('Column taster_twitter_handle doesn\'t exist.')

missing_values = df_clean.isnull().sum()

if missing_values.sum() > 0:
    print(f"Before : {len(df_clean)} lines")
    df_clean = df_clean.dropna()
    print(f"After : {len(df_clean)} lines")
    print(f"Deleted lines : {missing_values.sum()}")
else:
    print("No missing values.")
# Out:
# Before : 129971 lines
# After : 54170 lines
# Deleted lines : 94079

# %%
missing_values = df_clean.isnull().sum()
if missing_values.sum() > 0:
    print("\nMissing values per columns :")
    missing_percent = (missing_values / len(df_clean)) * 100
    missing_df = pd.DataFrame({
        'Missing values': missing_values,
        'Percentage': missing_percent
    })
    print(missing_df[missing_df['Missing values'] > 0].sort_values('Percentage', ascending=False))
else:
    print("No missing values.")
# Out:
# No missing values.

# %% [markdown]
# # Backup of cleaned Dataset

# %%
df_clean.to_csv("../data/cleaned/wine_data_cleaned.csv", index=False)
print(f"\nData saved : {len(df_clean)} lines")
# Out:
# Data saved : 54170 lines

# %%
# from geopy.geocoders import Nominatim
# from geopy.extra.rate_limiter import RateLimiter
# import pandas as pd
#
# # Initialiser avec rate limiter pour éviter de spammer l'API
# geolocator = Nominatim(user_agent="wine_app")
# geocode = RateLimiter(geolocator.geocode, min_delay_seconds=1)
#
# def get_coordinates(region):
#     """Récupère les coordonnées d'une région"""
#     if pd.isna(region):
#         return None, None
#
#     try:
#         location = geocode(region, timeout=10)
#         if location:
#             return location.latitude, location.longitude
#         else:
#             return None, None
#     except:
#         return None, None
#
# # Créer un DataFrame avec les régions uniques
# unique_regions = df_clean[['province', 'country', 'primary_region']].drop_duplicates().dropna(subset=['province'])
#
# regions_df = unique_regions.copy()
#
# print(f"Géocodage de {len(unique_regions)} régions...")
#
# regions_df['ICI'] = regions_df['country'] + ", " + regions_df['province'] + ", " + regions_df['primary_region']
# # Appliquer le géocodage
# regions_df[['latitude', 'longitude']] = regions_df['ICI'].apply(
#     lambda x: pd.Series(get_coordinates(x))
# )
#
# # Fusionner avec le DataFrame principal
# df_clean = df_clean.merge(
#     regions_df[['province', 'latitude', 'longitude']],
#     on='province',
#     how='left'
# )
#
# print(f"Géocodage terminé : {regions_df['latitude'].notna().sum()}/{len(unique_regions)} régions trouvées")

# %%
# from geopy.geocoders import Nominatim
# from geopy.extra.rate_limiter import RateLimiter
# import pandas as pd
#
# # Supprimer les anciennes colonnes latitude/longitude si elles existent
# for col in ['latitude', 'longitude', 'latitude_x', 'longitude_x', 'latitude_y', 'longitude_y']:
#     if col in df_clean.columns:
#         df_clean = df_clean.drop(columns=[col])
#         print(f"Suppression de {col}")
#
# # Initialiser avec rate limiter
# geolocator = Nominatim(user_agent="wine_app_v2")
# geocode = RateLimiter(geolocator.geocode, min_delay_seconds=1/20)
#
# def get_coordinates(region):
#     """Récupère les coordonnées d'une région"""
#     if pd.isna(region):
#         return None, None
#
#     try:
#         location = geocode(region, timeout=5)
#         if location:
#             return location.latitude, location.longitude
#         else:
#             return None, None
#     except:
#         return None, None
#
# # Créer un DataFrame avec les combinaisons uniques province + country + primary_region
# unique_regions = df_clean[['province', 'country', 'primary_region']].drop_duplicates().dropna(subset=['province'])
#
# regions_df = unique_regions.copy()
#
# print(f"Géocodage de {len(unique_regions)} combinaisons...")
#
# # ✅ Créer la requête (primary_region est souvent plus précis que province)
# regions_df['query'] = regions_df.apply(
#     lambda row: f"{row['primary_region']}, {row['province']}, {row['country']}"
#     if pd.notna(row['primary_region'])
#     else f"{row['province']}, {row['country']}",
#     axis=1
# )
#
# # Afficher quelques exemples de requêtes
# print("\nExemples de requêtes :")
# print(regions_df['query'].head(10).tolist())
#
# # Appliquer le géocodage
# regions_df[['latitude', 'longitude']] = regions_df['query'].apply(
#     lambda x: pd.Series(get_coordinates(x))
# )
#
# # ✅ IMPORTANT : Fusionner sur TOUTES les colonnes utilisées pour créer les combinaisons
# df_clean = df_clean.merge(
#     regions_df[['province', 'country', 'primary_region', 'latitude', 'longitude']],
#     on=['province', 'country', 'primary_region'],
#     how='left'
# )
#
# found = regions_df['latitude'].notna().sum()
# print(f"\n✅ Géocodage terminé : {found}/{len(unique_regions)} régions trouvées ({found/len(unique_regions)*100:.1f}%)")
#
# # Sauvegarder
# df_clean.to_csv("../data/cleaned/wine_data_province_lat_long.csv", index=False)
# print(f"💾 Fichier sauvegardé : {len(df_clean)} lignes")

# %%
# df_clean.to_csv("../data/cleaned/wine_data_province_lat_long.csv", index=False)
# print(f"\nData saved : {len(df_clean)} lines")
